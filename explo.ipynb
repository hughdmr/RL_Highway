# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("results/dqn_scratch/metrics.csv")

plt.figure(figsize=(8,5))
plt.plot(df["episode"], df["episode_reward"])
plt.xlabel("Episode")
plt.ylabel("Episode reward")
plt.title("Training reward")
plt.show()
